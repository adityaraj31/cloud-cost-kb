# %% [markdown]
# # Cloud Cost Data Exploration
# This notebook explores the AWS and Azure billing datasets to understand their structure and map them to the **FOCUS 1.0** ontology.

# %%
import pandas as pd
import numpy as np

# File paths
aws_path = 'data/aws_test-focus-00001.snappy_transformed.xls'
azure_path = 'data/focusazure_anon_transformed.xls'

# Load data
print("Loading AWS data...")
df_aws = pd.read_excel(aws_path)

print("Loading Azure data...")
df_azure = pd.read_excel(azure_path)

print("Data loaded successfully.")
# Out:
# Loading AWS data...
# Loading Azure data...
# Data loaded successfully.

# %% [markdown]
# ## 1. AWS Data Overview

# %%
df_aws.head()
# Out:
#   AvailabilityZone    BilledCost  BillingAccountId         BillingAccountName  \
# 0              NaN  9.929700e-06      428183493173  gsafj-nalpybhq-zcn57-cebq
# 1              NaN  0.000000e+00      428183493173  gsafj-nalpybhq-zcn57-cebq
# 2              NaN  1.010000e-08      428183493173  gsafj-nalpybhq-zcn57-cebq
# 3              NaN  1.059541e-03      428183493173  gsafj-nalpybhq-zcn57-cebq
# 4              NaN  0.000000e+00      428183493173  gsafj-nalpybhq-zcn57-cebq
#
#   BillingCurrency           BillingPeriodEnd         BillingPeriodStart  \
# 0             USD  2025-04-01 00:00:00+00:00  2025-03-01 00:00:00+00:00
# 1             USD  2025-04-01 00:00:00+00:00  2025-03-01 00:00:00+00:00
# 2             USD  2025-04-01 00:00:00+00:00  2025-03-01 00:00:00+00:00
# 3             USD  2025-04-01 00:00:00+00:00  2025-03-01 00:00:00+00:00
# 4             USD  2025-04-01 00:00:00+00:00  2025-03-01 00:00:00+00:00
#
#   ChargeCategory  ChargeClass  \
# ...

# %%
df_aws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 48 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AvailabilityZone            32 non-null     object
#  1   BilledCost                  1000 non-null   float64
#  2   BillingAccountId            1000 non-null   int64
#  3   BillingAccountName          1000 non-null   object
#  4   BillingCurrency             1000 non-null   object
#  5   BillingPeriodEnd            1000 non-null   object
#  6   BillingPeriodStart          1000 non-null   object
#  7   ChargeCategory              1000 non-null   object
#  8   ChargeClass                 0 non-null      float64
#  9   ChargeDescription           1000 non-null   object
#  10  ChargeFrequency             1000 non-null   object
#  11  ChargePeriodEnd             1000 non-null   object
#  12  ChargePeriodStart           1000 non-null   object
# ...

# %% [markdown]
# ## 2. Azure Data Overview

# %%
df_azure.head()
# Out:
#    billedcost                                   billingaccountid  \
# 0    0.033876  /providers/Microsoft.Billing/billingAccounts/9...
# 1    0.000000  /providers/Microsoft.Billing/billingAccounts/9...
# 2    0.000296  /providers/Microsoft.Billing/billingAccounts/9...
# 3    0.000084  /providers/Microsoft.Billing/billingAccounts/9...
# 4    0.000128  /providers/Microsoft.Billing/billingAccounts/9...
#
#   billingaccountname billingaccounttype billingcurrency billingperiodend  \
# 0  Genafcbeg sbe AFJ    Billing Account             AUD       2025-02-01
# 1  Genafcbeg sbe AFJ    Billing Account             AUD       2025-02-01
# 2  Genafcbeg sbe AFJ    Billing Account             AUD       2025-02-01
# 3  Genafcbeg sbe AFJ    Billing Account             AUD       2025-02-01
# 4  Genafcbeg sbe AFJ    Billing Account             AUD       2025-02-01
#
#   billingperiodstart chargecategory  chargeclass  \
# 0         2025-01-01          Usage          NaN
# ...

# %%
df_azure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 96 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   billedcost                  999 non-null    float64
#  1   billingaccountid            999 non-null    object
#  2   billingaccountname          999 non-null    object
#  3   billingaccounttype          999 non-null    object
#  4   billingcurrency             999 non-null    object
#  5   billingperiodend            999 non-null    datetime64[ns]
#  6   billingperiodstart          999 non-null    datetime64[ns]
#  7   chargecategory              999 non-null    object
#  8   chargeclass                 0 non-null      float64
#  9   chargedescription           999 non-null    object
#  10  chargefrequency             999 non-null    object
#  11  chargeperiodend             999 non-null    datetime64[ns]
# ...

# %% [markdown]
# Identify the columns in both datasets that match the FOCUS 1.0 classes like `CostRecord`, `Service`, `Resource`, etc.
